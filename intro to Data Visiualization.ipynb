# %%
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('data/coffees.csv')

# %%
data
# Out:
#               timestamp  coffees contributor
# 0   2011-10-03 08:22:00      397     Quentin
# 1   2011-10-04 11:48:00      410     Quentin
# 4   2011-10-05 10:47:00      464     Quentin
# 5   2011-10-05 13:15:00      481     Quentin
# 6   2011-10-06 07:21:00      503     Anthony
# 7   2011-10-06 10:04:00      513     Quentin
# 8   2011-10-06 12:14:00      539        Mike
# 9   2011-10-06 12:49:00      540     Quentin
# 10  2011-10-06 14:52:00      563         Ben
# 11  2011-10-07 07:34:00      581     Anthony
# 12  2011-10-07 08:37:00      587     Quentin
# 13  2011-10-07 11:09:00      605     Quentin
# 14  2011-10-07 13:14:00      616        Mike
# 16  2011-10-07 15:20:00      626      Mike M
# 17  2011-10-07 16:50:00      635      Mike M
# 18  2011-10-09 16:53:00      650        Colm
# 19  2011-10-10 07:29:00      656     Anthony
# 20  2011-10-10 10:13:00      673     Quentin
# 21  2011-10-10 13:41:00      694      Mike M
# 22  2011-10-10 14:02:00      699     Quentin
# ...

# %%
data.head()
# Out:
#             timestamp  coffees contributor
# 0 2011-10-03 08:22:00      397     Quentin
# 1 2011-10-04 11:48:00      410     Quentin
# 4 2011-10-05 10:47:00      464     Quentin
# 5 2011-10-05 13:15:00      481     Quentin
# 6 2011-10-06 07:21:00      503     Anthony

# %%
data.describe()
# Out:
#             coffees
# count    657.000000
# mean    8568.471842
# std     4600.215049
# min      397.000000
# 25%     4986.000000
# 50%     9172.000000
# 75%    11562.000000
# max    24463.000000

# %%
data.coffees.head()
# Out:
# 0    397
# 1    410
# 4    464
# 5    481
# 6    503
# Name: coffees, dtype: int32

# %%
type(data.loc[2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [2] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-2cd603fed065> in <module>()
# ----> 1 type(data.loc[2])
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
# ...

# %%
data.dtypes
# Out:
# timestamp      datetime64[ns]
# coffees                 int32
# contributor            object
# dtype: object

# %%
data.coffees = pd.to_numeric(data.coffees,errors="coerce")

# %%
data.head()
# Out:
#             timestamp  coffees contributor
# 0 2011-10-03 08:22:00      397     Quentin
# 1 2011-10-04 11:48:00      410     Quentin
# 4 2011-10-05 10:47:00      464     Quentin
# 5 2011-10-05 13:15:00      481     Quentin
# 6 2011-10-06 07:21:00      503     Anthony

# %%
data.dtypes
# Out:
# timestamp      datetime64[ns]
# coffees                 int32
# contributor            object
# dtype: object

# %%
data.dropna(inplace=True)

# %%
data.coffees = data.coffees.astype(int)

# %%
data.coffees.dtypes
# Out:
# dtype('int32')

# %%
data.dtypes
# Out:
# timestamp      datetime64[ns]
# coffees                 int32
# contributor            object
# dtype: object

# %%
#data.timestamp.dt.date

data.timestamp = pd.to_datetime(data.timestamp)

# %%
data.columns
# Out:
# Index(['timestamp', 'coffees', 'contributor'], dtype='object')

# %%
data.coffees.plot()

# %%
data
# Out:
#               timestamp  coffees contributor
# 0   2011-10-03 08:22:00      397     Quentin
# 1   2011-10-04 11:48:00      410     Quentin
# 4   2011-10-05 10:47:00      464     Quentin
# 5   2011-10-05 13:15:00      481     Quentin
# 6   2011-10-06 07:21:00      503     Anthony
# 7   2011-10-06 10:04:00      513     Quentin
# 8   2011-10-06 12:14:00      539        Mike
# 9   2011-10-06 12:49:00      540     Quentin
# 10  2011-10-06 14:52:00      563         Ben
# 11  2011-10-07 07:34:00      581     Anthony
# 12  2011-10-07 08:37:00      587     Quentin
# 13  2011-10-07 11:09:00      605     Quentin
# 14  2011-10-07 13:14:00      616        Mike
# 16  2011-10-07 15:20:00      626      Mike M
# 17  2011-10-07 16:50:00      635      Mike M
# 18  2011-10-09 16:53:00      650        Colm
# 19  2011-10-10 07:29:00      656     Anthony
# 20  2011-10-10 10:13:00      673     Quentin
# 21  2011-10-10 13:41:00      694      Mike M
# 22  2011-10-10 14:02:00      699     Quentin
# ...

# %%
x=[1, 2, 4, 5]
y=[2, 4, 5, 6]
plt.plot(x,y)
plt.show()

# %%
x = [1, 2, 3]
y = [1, 4, 9]
z = [2, 5, 10]
plt.plot(y, x)
plt.plot(x, z)
plt.title('Test plot')
plt.xlabel('x')
plt.ylabel('y and y')
plt.legend(['this is x', 'this is y'])
plt.show()

# %%
data.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-118f55e0b3d0> in <module>()
# ----> 1 data.plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ...

# %%
#plt.plot(data.timestamp.dt.date,data.coffees)
plt.plot([1,2,3],[3,4,5])
#data.timestamp.dt.date.dtype
data.dtypes
# Out:
# timestamp      datetime64[ns]
# coffees                 int32
# contributor            object
# dtype: object

# %%
data[data.timestamp<"2013-03-01"]
# Out:
#               timestamp  coffees contributor
# 0   2011-10-03 08:22:00      397     Quentin
# 1   2011-10-04 11:48:00      410     Quentin
# 4   2011-10-05 10:47:00      464     Quentin
# 5   2011-10-05 13:15:00      481     Quentin
# 6   2011-10-06 07:21:00      503     Anthony
# 7   2011-10-06 10:04:00      513     Quentin
# 8   2011-10-06 12:14:00      539        Mike
# 9   2011-10-06 12:49:00      540     Quentin
# 10  2011-10-06 14:52:00      563         Ben
# 11  2011-10-07 07:34:00      581     Anthony
# 12  2011-10-07 08:37:00      587     Quentin
# 13  2011-10-07 11:09:00      605     Quentin
# 14  2011-10-07 13:14:00      616        Mike
# 16  2011-10-07 15:20:00      626      Mike M
# 17  2011-10-07 16:50:00      635      Mike M
# 18  2011-10-09 16:53:00      650        Colm
# 19  2011-10-10 07:29:00      656     Anthony
# 20  2011-10-10 10:13:00      673     Quentin
# 21  2011-10-10 13:41:00      694      Mike M
# 22  2011-10-10 14:02:00      699     Quentin
# ...

# %%
data = data[data.timestamp<"2013-03-01"]

# %%
plt.plot(data.timestamp.dt.date,data.coffees,".-")
plt.plot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-724b497b4e81> in <module>()
# ----> 1 plt.plot(data.timestamp.dt.date,data.coffees,".-").figsize(15,4)
#       2 plt.plot
#
# AttributeError: 'list' object has no attribute 'figsize'

# %%
data.contributor.head()

# %%
data.contributor.value_counts()
# Out:
# Quentin    354
# Mike       152
# Sergio      89
# Mike M      29
# Colm        12
# Anthony      4
# Ben          3
# Stefano      2
# Arturo       1
# Name: contributor, dtype: int64

# %%
data.contributor.value_counts().plot(kind="bar")

# %%
weekdays = data.timestamp.dt.weekday

# %%
weekdays
# Out:
# 0      0
# 1      1
# 4      2
# 5      2
# 6      3
# 7      3
# 8      3
# 9      3
# 10     3
# 11     4
# 12     4
# 13     4
# 14     4
# 16     4
# 17     4
# 18     6
# 19     0
# 20     0
# 21     0
# 22     0
# 23     0
# 24     1
# 25     2
# 26     2
# 27     2
# 28     2
# 29     2
# 30     2
# 31     3
# 32     3
#       ..
# 627    1
# 628    1
# 629    4
# 630    1
# 631    2
# 632    3
# 633    4
# 634    4
# 635    4
# 636    1
# 637    2
# 638    2
# 639    3
# 640    0
# 643    0
# 644    1
# 645    1
# 646    0
# 647    2
# 648    3
# 649    1
# 650    1
# 651    2
# 652    5
# 654    0
# 655    3
# 656    3
# 657    0
# 658    0
# 659    2
# Name: timestamp, Length: 646, dtype: int64

# %%
data = data.assign(weekdays=weekdays)

# %%
days_of_week = ['Monday','Tuesday','Wednessday','Thursday','Friday','Saturday','Sunday']
data.weekdays = data.weekdays.apply(lambda x:days_of_week[x] )

# %%
data
# Out:
#               timestamp  coffees contributor    weekdays
# 0   2011-10-03 08:22:00      397     Quentin      Monday
# 1   2011-10-04 11:48:00      410     Quentin     Tuesday
# 4   2011-10-05 10:47:00      464     Quentin  Wednessday
# 5   2011-10-05 13:15:00      481     Quentin  Wednessday
# 6   2011-10-06 07:21:00      503     Anthony    Thursday
# 7   2011-10-06 10:04:00      513     Quentin    Thursday
# 8   2011-10-06 12:14:00      539        Mike    Thursday
# 9   2011-10-06 12:49:00      540     Quentin    Thursday
# 10  2011-10-06 14:52:00      563         Ben    Thursday
# 11  2011-10-07 07:34:00      581     Anthony      Friday
# 12  2011-10-07 08:37:00      587     Quentin      Friday
# 13  2011-10-07 11:09:00      605     Quentin      Friday
# 14  2011-10-07 13:14:00      616        Mike      Friday
# 16  2011-10-07 15:20:00      626      Mike M      Friday
# 17  2011-10-07 16:50:00      635      Mike M      Friday
# ...

# %%
weekdays_count = data.groupby('weekdays').count()

# %%
weekdays_count
# Out:
#             timestamp  coffees  contributor
# weekdays
# Friday            114      114          114
# Monday            145      145          145
# Saturday           29       29           29
# Sunday             13       13           13
# Thursday          117      117          117
# Tuesday            97       97           97
# Wednessday        131      131          131

# %%
weekdays_count = weekdays_count.loc[days_of_week]

# %%
weekdays_count
# Out:
#             timestamp  coffees  contributor
# weekdays
# Monday            145      145          145
# Tuesday            97       97           97
# Wednessday        131      131          131
# Thursday          117      117          117
# Friday            114      114          114
# Saturday           29       29           29
# Sunday             13       13           13

# %%
weekdays_count.timestamp.plot(kind="bar", title="Datapoints added on each weekday" )

# %%
data.index = data.timestamp

# %%
data.index
